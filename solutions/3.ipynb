# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/hidden_number.csv')

# %%
plt.scatter(df['x'], df['y'], c=df['color'])

# %%
df_red = df[ df['color'] == 'red' ]

# %%
plt.scatter(df_red['x'], df_red['y'], c=df_red['color'])
