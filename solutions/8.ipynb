# %%
import pandas as pd

# %%
df = pd.read_csv('../data/mlb_teams.csv')

# %%
df.columns
# Out:
# Index(['yearID', 'lgID', 'teamID', 'franchID', 'divID', 'Rank', 'G', 'Ghome',
#        'W', 'L', 'DivWin', 'WCWin', 'LgWin', 'WSWin', 'R', 'AB', 'H', '2B',
#        '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'HBP', 'SF', 'RA', 'ER', 'ERA',
#        'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E', 'DP', 'FP',
#        'name', 'park', 'attendance', 'BPF', 'PPF', 'teamIDBR',
#        'teamIDlahman45', 'teamIDretro'],
#       dtype='object')

# %%
df[ (df['franchID'] == 'STL') & (df['yearID'] <= 2010) & (df['yearID'] >= 2000) ]
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome    W   L  ...  \
# 2351    2000   NL    SLN      STL     C     1  162   81.0   95  67  ...
# 2381    2001   NL    SLN      STL     C     2  162   82.0   93  69  ...
# 2411    2002   NL    SLN      STL     C     1  162   81.0   97  65  ...
# 2441    2003   NL    SLN      STL     C     3  162   81.0   85  77  ...
# 2471    2004   NL    SLN      STL     C     1  162   81.0  105  57  ...
# 2500    2005   NL    SLN      STL     C     1  162   81.0  100  62  ...
# 2530    2006   NL    SLN      STL     C     1  161   80.0   83  78  ...
# 2560    2007   NL    SLN      STL     C     3  162   81.0   78  84  ...
# 2590    2008   NL    SLN      STL     C     4  162   81.0   86  76  ...
# 2620    2009   NL    SLN      STL     C     1  162   81.0   91  71  ...
# 2650    2010   NL    SLN      STL     C     2  162   81.0   86  76  ...
#
#          DP     FP                 name               park  attendance  BPF  \
# ...

# %%
df[ (df['franchID'] == 'STL') & (df['yearID'] <= 2010) & (df['yearID'] >= 2000) ]['HR'].sum()
# Out:
# 1998
